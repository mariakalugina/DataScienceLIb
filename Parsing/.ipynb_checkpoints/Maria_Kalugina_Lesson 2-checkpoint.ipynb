# %%
#pip install unidecode

# %%
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import re
import unidecode
import pandas as pd

# %% [markdown]
# Здесь надо ввести текст для поиска вакансии

# %%
text= 'копирайтер'

# %%
main_link = 'https://hh.ru'
params = {'L_save_area':'true',
          'clusters':'true',
         'enable_snippets':'true',
         'showClusters':'true'}
page = '0'

# %%
params['text'] = text
params['page'] = page

# %%
headers = {'User-Agent':'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/89.0.4389.72 Safari/537.36'}

# %%
response = requests.get(main_link+'/search/vacancy', params=params, headers=headers)

# %%
vacancies=[]
while True:
    next_page=None
    if response.ok:
        soup = bs(response.text, 'html.parser')
        next_page = soup.find('a',{'data-qa':"pager-next"})
        vacancies_list = soup.findAll('div', {'class':'vacancy-serp-item'})
        
        
        for vacancy in vacancies_list:
            vacancy_data = {}
            vacancy_all = vacancy.find('a',{'data-qa':'vacancy-serp__vacancy-title'})
            vacancy_link = vacancy_all['href']
            vacancy_name = vacancy_all.getText()
            vacancy_site = "hh.ru"
            vacancy_comp = vacancy.find('span',{'data-qa':'vacancy-serp__vacancy-compensation'})
            if (vacancy_comp!=None):
                #обрабатываем строку с зарплатой
                salary_str = vacancy_comp.getText()
                a = salary_str.split(' ')
                currency = a[-1]
                #смотрим - указан ли в зп диапазон
                salary_number = a[-2].split('-')
                #если да - то обрабатываем ситуацию, когда есть и максимальная, и минимальная зп
                if (len(salary_number)==2):
                    salary_min = unidecode.unidecode(salary_number[0])
                    #salary_max = re.sub('\xa',' ',salary_number[1])
                    salary_max = unidecode.unidecode(salary_number[1])
                #если нет - то обрабатываем ситуацию, когда есть только минимальная зп
                else: 
                    if a[0]=='от':
                        salary_min=unidecode.unidecode(salary_number[0])
                        salary_max=None
                        #или когда есть только максимальная зп
                    else:
                        if a[1]=='до':   
                            salary_min=None
                            salary_max=unidecode.unidecode(salary_number[1])

            else: 
                salary_max=None
                salary_min=None
                currency= None
            
            vacancy_data['name'] = vacancy_name
            vacancy_data['link'] = vacancy_link
            vacancy_data['from_site'] = vacancy_site
            vacancy_data['min_compensation'] = salary_min
            vacancy_data['max_compensation'] = salary_max
            vacancy_data['currency'] = currency
            vacancies.append(vacancy_data)
            
        if (next_page!=None):
            next_page_link = main_link+next_page['href']
            response = requests.get(next_page_link, headers=headers)
        else: break

# %%
vacancies
# Out:
# [{'name': 'Переводчик-копирайтер со знанием английского языка',
#   'link': 'https://samara.hh.ru/vacancy/43079444?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '400',
#   'max_compensation': '1 000',
#   'currency': 'USD'},
#  {'name': 'Copywriter',
#   'link': 'https://samara.hh.ru/vacancy/42414843?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Проектный менеджер (копирайтер)',
#   'link': 'https://samara.hh.ru/vacancy/42970648?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42909347?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': '60 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42928836?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/40384649?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42909511?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '1 000',
#   'max_compensation': None,
#   'currency': 'бел.\xa0руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42909452?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '60 000',
#   'currency': 'руб.'},
#  {'name': 'SEO копирайтер (финансовый портал)',
#   'link': 'https://samara.hh.ru/vacancy/42657953?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42909420?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '60 000',
#   'currency': 'руб.'},
#  {'name': 'Писатель-копирайтер (удалённо)',
#   'link': 'https://samara.hh.ru/vacancy/42533970?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер (удаленно)',
#   'link': 'https://samara.hh.ru/vacancy/43079184?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43045767?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '800',
#   'max_compensation': None,
#   'currency': 'USD'},
#  {'name': 'Копирайтер / SEO-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43050825?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '15 000',
#   'max_compensation': '20 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42321499?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Креативный копирайтер/Copywriter',
#   'link': 'https://samara.hh.ru/vacancy/40793039?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '1 300',
#   'max_compensation': None,
#   'currency': 'USD'},
#  {'name': 'Журналист / автор статей (копирайтер в маркетплейс) удаленно',
#   'link': 'https://samara.hh.ru/vacancy/42778355?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43046840?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42806982?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': '40 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43024596?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42996917?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42803730?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер/Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42624059?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '300 000',
#   'max_compensation': '400 000',
#   'currency': 'KZT'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43056864?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43032652?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '70 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43032654?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '70 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43039968?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43041542?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': '80 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер/автор/журналист в бренд-медиа',
#   'link': 'https://samara.hh.ru/vacancy/42444646?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '45 000',
#   'max_compensation': '55 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43032653?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '70 000',
#   'currency': 'руб.'},
#  {'name': 'Журналист-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43093970?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43049064?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42664557?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '58 000',
#   'max_compensation': '58 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42919662?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42513980?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '10 000',
#   'max_compensation': '20 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42492920?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '15 000',
#   'max_compensation': '15 000',
#   'currency': 'грн.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43056159?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '15 000',
#   'max_compensation': '15 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42868287?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '15 000',
#   'max_compensation': '15 000',
#   'currency': 'руб.'},
#  {'name': 'Журналист-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42678079?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43089202?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42773985?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Главный редактор на YouTube-проект / Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43014518?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': '150 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43047881?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '52 000',
#   'max_compensation': '67 000',
#   'currency': 'руб.'},
#  {'name': 'Скрипт дизайнер (копирайтер)',
#   'link': 'https://samara.hh.ru/vacancy/42705004?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '52 000',
#   'max_compensation': '67 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42694965?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер / Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42735463?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '70 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Журналист-копирайтер/редактор по литературной тематике',
#   'link': 'https://samara.hh.ru/vacancy/43042904?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '10 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Технический писатель / копирайтер (редактор) удаленно',
#   'link': 'https://samara.hh.ru/vacancy/43031603?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '60 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/40666042?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер (удаленка)',
#   'link': 'https://samara.hh.ru/vacancy/42829376?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '15 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42826295?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Креативный копирайтер / Креатор',
#   'link': 'https://samara.hh.ru/vacancy/41710868?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43090923?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '300',
#   'max_compensation': '500',
#   'currency': 'USD'},
#  {'name': 'Журналист-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43069586?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43055793?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер со знанием английского языка (удаленно)',
#   'link': 'https://samara.hh.ru/vacancy/43079723?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42675747?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер / copywriter (удаленно, итальянский язык)',
#   'link': 'https://samara.hh.ru/vacancy/42717223?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42335146?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43032651?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '70 000',
#   'currency': 'руб.'},
#  {'name': 'Автор - копирайтер статей для написания чек - листов в сфере SMM',
#   'link': 'https://samara.hh.ru/vacancy/43087844?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Контент-менеджер/Копирайтер (SMM-менеджер)',
#   'link': 'https://samara.hh.ru/vacancy/42921432?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '70 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Креативный копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43044949?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер-сценарист',
#   'link': 'https://samara.hh.ru/vacancy/43058902?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Журналист-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42844949?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер (copywriter, удаленно, испанский язык)',
#   'link': 'https://samara.hh.ru/vacancy/42717203?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Журналист-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42578789?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42836480?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42741746?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42582534?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Удаленный копирайтер / специалист по управлению репутацией',
#   'link': 'https://samara.hh.ru/vacancy/43092713?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '60 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42295346?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42338351?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '40 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер в контент отдел',
#   'link': 'https://samara.hh.ru/vacancy/42971087?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '35 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/41949980?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '65 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Журналист-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42860196?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер SMM',
#   'link': 'https://samara.hh.ru/vacancy/43056991?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43088691?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42542475?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '20 000',
#   'max_compensation': '26 600',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/41832604?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Редактор (копирайтер)',
#   'link': 'https://samara.hh.ru/vacancy/42461119?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43027678?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Менеджер по PR/ Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42823970?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '70 000',
#   'max_compensation': '100 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/41643260?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '3 500 000',
#   'max_compensation': None,
#   'currency': 'сум'},
#  {'name': 'Контент менеджер (копирайтер)',
#   'link': 'https://samara.hh.ru/vacancy/42762945?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43009534?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '3 500 000',
#   'max_compensation': '4 000 000',
#   'currency': 'сум'},
#  {'name': 'Контент-менеджер / Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43073509?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '30 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42630185?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Copywriter / Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43056883?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Медицинский редактор/Медицинский копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42652055?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': '70 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42693916?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '15 000',
#   'max_compensation': '17 000',
#   'currency': 'грн.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43064655?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер/Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42982212?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер/copywriter (удаленно, французкий язык)',
#   'link': 'https://samara.hh.ru/vacancy/42717188?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Журналист-копирайтер в PR-агентство',
#   'link': 'https://samara.hh.ru/vacancy/42845023?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Copywriter',
#   'link': 'https://samara.hh.ru/vacancy/42293661?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Маркетолог (СММ / Копирайтер)',
#   'link': 'https://samara.hh.ru/vacancy/42806355?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '28 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42201536?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '15 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42245995?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер издательства',
#   'link': 'https://samara.hh.ru/vacancy/41725944?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '35 000',
#   'max_compensation': '40 000',
#   'currency': 'руб.'},
#  {'name': 'SEO-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43037941?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер/Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42982213?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер / Copywriter',
#   'link': 'https://samara.hh.ru/vacancy/42457906?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Copywriter / Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43056884?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Креативный копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42528445?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер/Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42567340?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '150 000',
#   'max_compensation': None,
#   'currency': 'KZT'},
#  {'name': 'Копирайтер в коммуникационное агентство',
#   'link': 'https://samara.hh.ru/vacancy/42935747?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер в блог Digital Academy',
#   'link': 'https://samara.hh.ru/vacancy/42428826?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер / copywriter (удаленно, английский язык)',
#   'link': 'https://samara.hh.ru/vacancy/42717229?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер PREMIER',
#   'link': 'https://samara.hh.ru/vacancy/42778870?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/41880146?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер/контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/43068206?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'SEO-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43089550?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Креативный копирайтер / Креатор (косметика)',
#   'link': 'https://samara.hh.ru/vacancy/42989133?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер / copywriter (удаленно, немецкий язык)',
#   'link': 'https://samara.hh.ru/vacancy/42717069?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Контент-менеджер, копирайтер, редактор сайта',
#   'link': 'https://samara.hh.ru/vacancy/42401064?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '35 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42983243?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42768784?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '35 000',
#   'max_compensation': '40 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43081431?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42493425?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Редактор | Копирайтер для статей в блог, писем и лендингов',
#   'link': 'https://samara.hh.ru/vacancy/42680700?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '33 000',
#   'max_compensation': '40 000',
#   'currency': 'руб.'},
#  {'name': 'Корректор-редактор',
#   'link': 'https://samara.hh.ru/vacancy/43081124?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Маркетолог-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42741451?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '1 000',
#   'max_compensation': None,
#   'currency': 'USD'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42485011?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '40 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42925168?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Журналист-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42999438?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '18 000',
#   'max_compensation': '30 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42193273?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43048071?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/41693093?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43038448?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Журналист-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/38010824?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Контент-менеджер \\ Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42654045?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер / Редактор блога',
#   'link': 'https://samara.hh.ru/vacancy/42990328?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер/Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42961254?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/40973001?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '20 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер/Специалист по контенту',
#   'link': 'https://samara.hh.ru/vacancy/42395697?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Контент-менеджер / Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43073168?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер технических текстов для видео-обзоров',
#   'link': 'https://samara.hh.ru/vacancy/42470383?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '45 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Copywriter',
#   'link': 'https://samara.hh.ru/vacancy/43091739?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер-Copywriter/Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/43063770?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер / Писатель для блога',
#   'link': 'https://samara.hh.ru/vacancy/42965768?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '70 000',
#   'currency': 'руб.'},
#  {'name': 'Автор / Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/37795977?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '27 000',
#   'max_compensation': '30 000',
#   'currency': 'руб.'},
#  {'name': 'SMM-менеджер, ведение соц.сетей',
#   'link': 'https://samara.hh.ru/vacancy/42618251?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42792567?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер для email-рассылок (удаленно)',
#   'link': 'https://samara.hh.ru/vacancy/40027388?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/39632731?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42829661?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер/Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42982211?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер-рерайтер',
#   'link': 'https://samara.hh.ru/vacancy/42987896?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/39683462?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Редактор/копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42642122?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '80 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Контент-редактор',
#   'link': 'https://samara.hh.ru/vacancy/42933636?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер-Райтер / Copywriter (English С2), удаленно / remote',
#   'link': 'https://samara.hh.ru/vacancy/42544777?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42979641?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер на английском языке (контент менеджер сайта)',
#   'link': 'https://samara.hh.ru/vacancy/42873711?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '4 000 000',
#   'max_compensation': None,
#   'currency': 'сум'},
#  {'name': 'SEO копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42598159?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '45 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Контент-менеджер, копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42777274?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42966915?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '20 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'SMM-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43044970?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/40285938?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер на YouTube канал',
#   'link': 'https://samara.hh.ru/vacancy/43080808?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '70 000',
#   'currency': 'руб.'},
#  {'name': 'Креатор-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42953924?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '80 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/41068795?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '80 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42487808?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '80 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер / рерайтер (контент-менеджер)',
#   'link': 'https://samara.hh.ru/vacancy/42954424?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Автор статей / копирайтер (IT-журналистика)',
#   'link': 'https://samara.hh.ru/vacancy/42935599?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42946542?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '20 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42961049?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '26 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер-аналитик',
#   'link': 'https://samara.hh.ru/vacancy/42924216?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер/рерайтер',
#   'link': 'https://samara.hh.ru/vacancy/42946060?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Журналист-копирайтер (в компанию резидент "Сколково")',
#   'link': 'https://samara.hh.ru/vacancy/42971990?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Журналист-копирайтер / автор новостей (копирайтер)',
#   'link': 'https://samara.hh.ru/vacancy/42962459?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер/ контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/43032172?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43092416?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '15 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'SMM-менеджер / Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42779248?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер/журналист',
#   'link': 'https://samara.hh.ru/vacancy/42261545?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'SMM-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42993531?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '100 000',
#   'max_compensation': '120 000',
#   'currency': 'KZT'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42897866?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': '90 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42987345?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42993759?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер / Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/40916651?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер (медицина)',
#   'link': 'https://samara.hh.ru/vacancy/42964508?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Копирайтер (в офисе)',
#   'link': 'https://samara.hh.ru/vacancy/42339275?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '20 000',
#   'max_compensation': '35 000',
#   'currency': 'руб.'},
#  {'name': 'Дизайнер-копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/43087411?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
#   'link': 'https://samara.hh.ru/vacancy/42953932?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '33 000',
#   'max_compensation': '45 000',
#   'currency': 'руб.'},
#  {'name': 'Копирайтер',
# ...
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/40623188?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/40623240?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/40666106?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'CRM-маркетолог / Email-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/41893063?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'CRM-маркетолог (email-маркетолог)',
#   'link': 'https://samara.hh.ru/vacancy/42809731?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Менеджер по работе с откликами в онлайн',
#   'link': 'https://samara.hh.ru/vacancy/42540394?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'SMM-менеджер (в агентство интернет-маркетинга)',
#   'link': 'https://samara.hh.ru/vacancy/42486589?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Контент-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42334801?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/42570468?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Помощник SEO-специалиста',
#   'link': 'https://samara.hh.ru/vacancy/43010114?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Менеджер по продвижению',
#   'link': 'https://samara.hh.ru/vacancy/43035654?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Руководитель отдела маркетинга',
#   'link': 'https://samara.hh.ru/vacancy/42815500?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Таргетолог',
#   'link': 'https://samara.hh.ru/vacancy/40390963?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Директор по маркетингу',
#   'link': 'https://samara.hh.ru/vacancy/42704333?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '200 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/43082656?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '35 000',
#   'max_compensation': '80 000',
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/42009928?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'SEO-специалист',
#   'link': 'https://samara.hh.ru/vacancy/42935665?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': '90 000',
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог (стажер)',
#   'link': 'https://samara.hh.ru/vacancy/43058147?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'SEO-спеціаліст',
#   'link': 'https://samara.hh.ru/vacancy/42524376?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '10 000',
#   'max_compensation': '30 000',
#   'currency': 'грн.'},
#  {'name': 'Маркетинг-менеджер (аккаунт-менеджер) / стажер',
#   'link': 'https://samara.hh.ru/vacancy/42120164?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '25 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/42583388?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '50 000',
#   'max_compensation': '100 000',
#   'currency': 'руб.'},
#  {'name': 'Маркетолог-аналитик',
#   'link': 'https://samara.hh.ru/vacancy/42537819?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Junior SEO-специалист',
#   'link': 'https://samara.hh.ru/vacancy/43005978?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '20 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'SEO-специалист',
#   'link': 'https://samara.hh.ru/vacancy/42923465?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Менеджер проектов (маркетинг)',
#   'link': 'https://samara.hh.ru/vacancy/42875331?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': '110 000',
#   'currency': 'руб.'},
#  {'name': 'Дизайнер/Designer',
#   'link': 'https://samara.hh.ru/vacancy/42399290?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Ведущий маркетолог / Создание брендов на Amazon',
#   'link': 'https://samara.hh.ru/vacancy/42782635?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '150 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Арт-директор',
#   'link': 'https://samara.hh.ru/vacancy/43071246?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Middle SEO-специалист',
#   'link': 'https://samara.hh.ru/vacancy/42520708?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '1 000',
#   'max_compensation': None,
#   'currency': 'USD'},
#  {'name': 'Контент - менеджер со знанием английского языка',
#   'link': 'https://samara.hh.ru/vacancy/42548275?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Маркетинг-менеджер',
#   'link': 'https://samara.hh.ru/vacancy/42483065?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '600',
#   'max_compensation': None,
#   'currency': 'USD'},
#  {'name': 'Интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/41192558?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '50 000',
#   'currency': 'руб.'},
#  {'name': 'Менеджер проекта "Amazon"',
#   'link': 'https://samara.hh.ru/vacancy/42563677?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '1 500',
#   'max_compensation': None,
#   'currency': 'EUR'},
#  {'name': 'Маркетолог | Интернет-магазин мягкой мебели',
#   'link': 'https://samara.hh.ru/vacancy/42495400?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '90 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Креативный продюсер (направление Привлечения)',
#   'link': 'https://samara.hh.ru/vacancy/43038298?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Креативный продюсер (направление Привлечения)',
#   'link': 'https://samara.hh.ru/vacancy/43038299?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'ASO Specialist (GameDev)',
#   'link': 'https://samara.hh.ru/vacancy/42647596?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Менеджер проектов в инфобизнесе',
#   'link': 'https://samara.hh.ru/vacancy/43058821?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '80 000',
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог в онлайн школу',
#   'link': 'https://samara.hh.ru/vacancy/42830219?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '80 000',
#   'currency': 'руб.'},
#  {'name': 'Digital-специалист, интернет-маркетолог (seo оптимизатор/директолог) в офис',
#   'link': 'https://samara.hh.ru/vacancy/42533322?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': '100 000',
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/43037360?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '55 000',
#   'max_compensation': '65 000',
#   'currency': 'руб.'},
#  {'name': 'Маркетолог B2B',
#   'link': 'https://samara.hh.ru/vacancy/42377770?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '55 000',
#   'max_compensation': '65 000',
#   'currency': 'руб.'},
#  {'name': 'Директор по маркетингу',
#   'link': 'https://samara.hh.ru/vacancy/42716683?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Менеджер проектов (Внутренний PR)',
#   'link': 'https://samara.hh.ru/vacancy/41099142?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Менеджер по локализации',
#   'link': 'https://samara.hh.ru/vacancy/41857197?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '80 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Менеджер по локализации',
#   'link': 'https://samara.hh.ru/vacancy/41857198?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '80 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Ведущий интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/42681424?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Специалист по интернет-маркетингу',
#   'link': 'https://samara.hh.ru/vacancy/42987708?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Интернет-маркетолог / Junior',
#   'link': 'https://samara.hh.ru/vacancy/43093990?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '40 000',
#   'max_compensation': '70 000',
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог/таргетолог (facebook)',
#   'link': 'https://samara.hh.ru/vacancy/42805165?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '80 000',
#   'max_compensation': '500 000',
#   'currency': 'руб.'},
#  {'name': 'Креативний продюсер Департаменту кіносеріального виробництва',
#   'link': 'https://samara.hh.ru/vacancy/42431887?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Интернет - маркетолог (Таргетолог)',
#   'link': 'https://samara.hh.ru/vacancy/43049621?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '70 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Менеджер по маркетингу и PR (Mobile Marketing) / PR-manager',
#   'link': 'https://samara.hh.ru/vacancy/42744648?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Специалист по E-mail маркетингу',
#   'link': 'https://samara.hh.ru/vacancy/41037838?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '60 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/43017156?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '100 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Руководитель отдела контент-маркетинга',
#   'link': 'https://samara.hh.ru/vacancy/41556347?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'SEO-специалист',
#   'link': 'https://samara.hh.ru/vacancy/40668454?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '70 000',
#   'max_compensation': None,
#   'currency': 'руб.'},
#  {'name': 'Помощник CRM маркетолога',
#   'link': 'https://samara.hh.ru/vacancy/42957461?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': '30 000',
#   'max_compensation': '35 000',
#   'currency': 'руб.'},
#  {'name': 'Website editor / Account manager',
#   'link': 'https://samara.hh.ru/vacancy/42814996?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  {'name': 'Интернет-маркетолог',
#   'link': 'https://samara.hh.ru/vacancy/42886577?query=%D0%BA%D0%BE%D0%BF%D0%B8%D1%80%D0%B0%D0%B9%D1%82%D0%B5%D1%80',
#   'from_site': 'hh.ru',
#   'min_compensation': None,
#   'max_compensation': None,
#   'currency': None},
#  ...]

# %%
df = pd.DataFrame(vacancies)

# %%
df
# Out:
#                                                    name  \
# 0     Переводчик-копирайтер со знанием английского я...
# 1                                            Copywriter
# 2                       Проектный менеджер (копирайтер)
# 3                                            Копирайтер
# 4                                            Копирайтер
# ...                                                 ...
# 1995                                         Copywriter
# 1996                                         Copywriter
# 1997                                         Copywriter
# 1998                                         Copywriter
# 1999                                         Copywriter
#
#                                                    link from_site  \
# 0     https://samara.hh.ru/vacancy/43079444?query=%D...     hh.ru
# 1     https://samara.hh.ru/vacancy/42414843?query=%D...     hh.ru
# 2     https://samara.hh.ru/vacancy/42970648?query=%D...     hh.ru
# 3     https://samara.hh.ru/vacancy/42909347?query=%D...     hh.ru
# 4     https://samara.hh.ru/vacancy/42928836?query=%D...     hh.ru
# ...                                                 ...       ...
# 1995  https://samara.hh.ru/vacancy/42085981?query=%D...     hh.ru
# 1996  https://samara.hh.ru/vacancy/42085982?query=%D...     hh.ru
# 1997  https://samara.hh.ru/vacancy/42085983?query=%D...     hh.ru
# 1998  https://samara.hh.ru/vacancy/42085984?query=%D...     hh.ru
# 1999  https://samara.hh.ru/vacancy/42085985?query=%D...     hh.ru
#
#      min_compensation max_compensation currency
# 0                 400            1 000      USD
# 1                None             None     None
# 2                None             None     None
# 3              50 000           60 000     руб.
# 4                None             None     None
# ...               ...              ...      ...
# 1995             None             None     None
# 1996             None             None     None
# 1997             None             None     None
# 1998             None             None     None
# 1999             None             None     None
#
# [2000 rows x 6 columns]
